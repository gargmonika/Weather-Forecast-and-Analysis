# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather_uncleaned_dataset.csv')
df
# Out:
#                       weather_dataset Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                          tableName         NaN        NaN        NaN
# 1                                 NaN        NaN        NaN        NaN
# 2                   Date\tVARCHAR(512        NaN        NaN        NaN
# 3                 temperature\tDOUBLE        NaN        NaN        NaN
# 4         Average humidity (%\tDOUBLE        NaN        NaN        NaN
# ...                               ...        ...        ...        ...
# 3926                      2022-07-25'     '62.8'     '60.0'     '48.1'
# 3927                      2022-07-26'     '60.6'     '68.0'     '48.9'
# 3928                      2022-07-27'     '61.7'     '64.0'     '47.4'
# 3929                      2022-07-28'     '60.5'     '61.0'     '45.3'
# 3930                      2022-07-28'     '60.5'     '61.0'     '45.3'
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
df.head(27)
# Out:
#                         weather_dataset Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                            tableName         NaN        NaN        NaN
# 1                                   NaN        NaN        NaN        NaN
# 2                     Date\tVARCHAR(512        NaN        NaN        NaN
# 3                   temperature\tDOUBLE        NaN        NaN        NaN
# 4           Average humidity (%\tDOUBLE        NaN        NaN        NaN
# 5          Average dewpoint (°F\tDOUBLE        NaN        NaN        NaN
# 6         Average barometer (in\tDOUBLE        NaN        NaN        NaN
# 7        Average windspeed (mph\tDOUBLE        NaN        NaN        NaN
# 8        Average gustspeed (mph\tDOUBLE        NaN        NaN        NaN
# 9       Average direction (°deg\tDOUBLE        NaN        NaN        NaN
# 10       Rainfall for month (in\tDOUBLE        NaN        NaN        NaN
# 11        Rainfall for year (in\tDOUBLE        NaN        NaN        NaN
# ...

# %%
df_new=df.drop(df.index[0:27])

# %%
list(df_new)    #get column names of dataset
# Out:
# ['weather_dataset',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22']

# %%
df_new.head()
# Out:
#    weather_dataset    Unnamed: 1            Unnamed: 2             Unnamed: 3  \
# 27            Date   Temperature   Average humidity (%   Average dewpoint (°F
# 28     2022-01-01'        '37.8'                '35.0'                 '12.7'
# 29     2022-01-02'        '43.2'                '32.0'                 '14.7'
# 30     2022-01-03'        '25.7'                '60.0'                 '12.7'
# 31     2022-01-04'         '9.3'                '67.0'                  '0.1'
#
#                 Unnamed: 4               Unnamed: 5               Unnamed: 6  \
# 27   Average barometer (in   Average windspeed (mph   Average gustspeed (mph
# 28                  '29.7'                   '26.4'                   '36.8'
# 29                  '29.5'                   '12.8'                   '18.0'
# 30                  '29.7'                    '8.3'                   '12.2'
# 31                  '30.4'                    '2.9'                    '4.5'
#
# ...

# %%
df_new.columns.values
# Out:
# array(['weather_dataset', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'], dtype=object)

# %%
df_new.columns= df_new.iloc[0]

# %%
df_new
# Out:
# 27           Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 27           Date   Temperature   Average humidity (%   Average dewpoint (°F
# 28    2022-01-01'        '37.8'                '35.0'                 '12.7'
# 29    2022-01-02'        '43.2'                '32.0'                 '14.7'
# 30    2022-01-03'        '25.7'                '60.0'                 '12.7'
# 31    2022-01-04'         '9.3'                '67.0'                  '0.1'
# ...           ...           ...                   ...                    ...
# 3926  2022-07-25'        '62.8'                '60.0'                 '48.1'
# 3927  2022-07-26'        '60.6'                '68.0'                 '48.9'
# 3928  2022-07-27'        '61.7'                '64.0'                 '47.4'
# 3929  2022-07-28'        '60.5'                '61.0'                 '45.3'
# 3930  2022-07-28'        '60.5'                '61.0'                 '45.3'
#
# ...

# %%
# df_new.drop[df_new.index[27], inplace=True]
df_new.drop(27,inplace=True)

# %%
df_new.reset_index(inplace=True)

# %%
df_new.drop('index', axis=1, inplace=True)

# %%
df_new
# Out:
# 27           Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0     2022-01-01'       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
# 27    Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %%
df_new.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object', name=27)

# %%
df_new.index.name

# %%
df_new.rename_axis(' ',inplace=True)

# %%
df_new.columns.name
# Out:
# 27

# %%
df_new.columns.name =' '

# %%
df_new
# Out:
#              Date  Temperature  Average humidity (%  Average dewpoint (°F  \
#
# 0     2022-01-01'       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %%
df_new.columns= ['date', 'temperature', 'average_humidity', 'average_dewpoint',
       'average_barometer','average_windspeed',
       'average_gustspeed', 'average_direction',
       'rainfall_for_month', 'rainfall_for_year',
       'maximum_rain_per_minute', 'maximum_temperature',
       'minimum_temperature', 'maximum_humidity',
       'minimum_humidity', 'maximum_pressure', 'minimum_pressure',
       'maximum_windspeed', 'maximum_gust_speed',
       'maximum_heat_index', 'date1', 'month', 'diff_pressure']

# %%
df_new
# Out:
#              date temperature average_humidity average_dewpoint  \
#
# 0     2022-01-01'      '37.8'           '35.0'           '12.7'
# 1     2022-01-02'      '43.2'           '32.0'           '14.7'
# 2     2022-01-03'      '25.7'           '60.0'           '12.7'
# 3     2022-01-04'       '9.3'           '67.0'            '0.1'
# 4     2022-01-05'      '23.5'           '30.0'           '-5.3'
# ...           ...         ...              ...              ...
# 3898  2022-07-25'      '62.8'           '60.0'           '48.1'
# 3899  2022-07-26'      '60.6'           '68.0'           '48.9'
# 3900  2022-07-27'      '61.7'           '64.0'           '47.4'
# 3901  2022-07-28'      '60.5'           '61.0'           '45.3'
# 3902  2022-07-28'      '60.5'           '61.0'           '45.3'
#
#      average_barometer average_windspeed average_gustspeed average_direction  \
#
# 0               '29.7'            '26.4'            '36.8'           '274.0'
# ...

# %%
for col in df_new.columns:
    for i in df_new.loc[:,col]:
        
        i = i.replace("'",' ')
#         df_new.loc[i,col]=i
        print(i)
        
#         j= ' '
        
#         df_new.loc[range(0,3902),col]=values
#         print(values)
# Out:
# 2022-01-01
# 2022-01-02
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-01-07
# 2022-01-08
# 2022-01-09
# 2022-01-10
# 2022-01-11
# 2022-01-12
# 2022-01-13
# 2022-01-14
# 2022-01-15
# 2022-01-16
# 2022-01-17
# 2022-01-18
# 2022-01-19
# 2022-01-20
# 2022-01-21
# 2022-01-22
# 2022-01-23
# 2022-01-24
# 2022-01-25
# 2022-01-26
# 2022-01-27
# 2022-01-28
# 2022-01-29
# 2022-01-30
# 2022-01-31
# 2022-02-01
# 2022-02-02
# 2022-02-03
# 2022-02-04
# 2022-02-05
# 2022-02-06
# 2022-02-07
# 2022-02-08
# 2022-02-09
# 2022-02-10
# 2022-02-11
# 2022-02-12
# 2022-02-13
# 2022-02-14
# 2022-02-15
# 2022-02-16
# 2022-02-17
# 2022-02-18
# 2022-02-19
# 2022-02-20
# 2022-02-21
# 2022-02-22
# 2022-02-23
# 2022-02-24
# 2022-02-25
# 2022-02-26
# 2022-02-27
# 2022-02-28
# 2022-03-01
# 2022-03-02
# 2022-03-03
# 2022-03-04
# 2022-03-05
# 2022-03-06
# 2022-03-07
# 2022-03-08
# 2022-03-09
# 2022-03-10
# 2022-03-11
# 2022-03-12
# 2022-03-16
# 2022-03-17
# 2022-03-18
# 2022-03-19
# 2022-03-20
# ...

# %%
df_new

# %%
# df_new.loc[0,'date']
